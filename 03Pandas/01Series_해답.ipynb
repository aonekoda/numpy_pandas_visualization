# %% [markdown]
# # 실습하기

# %% [markdown]
# 1. 다음과 같은 시리즈 데이터를 생성하시오.
# ```
# >>> population = pd.Series([852469, 1015785, 485199], index=['San Francisco', 'San Jose', 'Sacramento'])
# ```

# %%
population = pd.Series([852469, 1015785, 485199, np.nan], index=['San Francisco', 'San Jose', 'Sacramento', 'Seoul'])
population
# Out:
# San Francisco     852469.0
# San Jose         1015785.0
# Sacramento        485199.0
# Seoul                  NaN
# dtype: float64

# %% [markdown]
# 2. population에서 인구 500000명 이상의 값을 출력하시오.

# %%
population[population > 500000]
# Out:
# San Francisco     852469.0
# San Jose         1015785.0
# dtype: float64

# %% [markdown]
# 3. population의 인덱스 명을 출력하시오.

# %%
population.index
# Out:
# Index(['San Francisco', 'San Jose', 'Sacramento', 'Seoul'], dtype='object')

# %% [markdown]
# 4. 'San Jose'의 인구수를 출력하시오.

# %%
population['San Jose']
# Out:
# 1015785.0

# %% [markdown]
# 5. 결측치를 0으로 대체하시오.

# %%
population = population.fillna(0)
population
# Out:
# San Francisco     852469.0
# San Jose         1015785.0
# Sacramento        485199.0
# Seoul                  0.0
# dtype: float64

# %% [markdown]
# 6. 인구의 평균과 최소, 최대값을 구하시오.

# %%
print('평균:', population.mean())
print('최소:', population.min())
print('최대:', population.max())
# Out:
# 평균: 588363.25
# 최소: 0.0
# 최대: 1015785.0
