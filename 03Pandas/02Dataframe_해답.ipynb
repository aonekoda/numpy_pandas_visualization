# %% [markdown]
# # 실습하기

# %% [markdown]
# 1. csv 파일을 데이터프레임으로 읽어 들인다.
#
# ```
# >>> movie = pd.read_csv('../data/movie.csv')
# ```

# %%
movie = pd.read_csv('../data/movie.csv')
movie.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b1d05605d33b> in <module>()
# ----> 1 movie = pd.read_csv('../data/movie.csv')
#       2 movie.head()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# 2. 읽어들인 데이터프레임의 컬럼이름을 확인해 본다.

# %%
movie.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3271 entries, 0 to 3270
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      3263 non-null   object
#  1   director_name              3211 non-null   object
#  2   num_critic_for_reviews     3260 non-null   float64
#  3   duration                   3267 non-null   float64
#  4   director_facebook_likes    3211 non-null   float64
#  5   actor_3_facebook_likes     3266 non-null   float64
#  6   actor_2_name               3268 non-null   object
#  7   actor_1_facebook_likes     3271 non-null   float64
#  8   gross                      3011 non-null   float64
#  9   genres                     3270 non-null   object
#  10  actor_1_name               3270 non-null   object
#  11  movie_title                3270 non-null   object
#  12  num_voted_users            3270 non-null   float64
#  13  cast_total_facebook_likes  3270 non-null   float64
#  14  actor_3_name               3265 non-null   object
#  15  facenumber_in_poster       3266 non-null   float64
#  16  plot_keywords              3232 non-null   object
#  17  movie_imdb_link            3270 non-null   object
#  18  num_user_for_reviews       3262 non-null   float64
#  19  language                   3266 non-null   object
#  20  country                    3267 non-null   object
#  21  content_rating             3200 non-null   object
#  22  budget                     3068 non-null   float64
#  23  title_year                 3206 non-null   float64
#  24  actor_2_facebook_likes     3267 non-null   float64
#  25  imdb_score                 3270 non-null   float64
#  26  aspect_ratio               3206 non-null   float64
#  27  movie_facebook_likes       3270 non-null   float64
# dtypes: float64(16), object(12)
# memory usage: 715.7+ KB

# %% [markdown]
# 3. movie 데이터프레임에서 감독의 이름이 "James Cameron"인 데이터를 조회하시오.

# %%
movie[movie['director_name']=='James Cameron']
# Out:
#       color  director_name  ...  aspect_ratio  movie_facebook_likes
# 0     Color  James Cameron  ...          1.78               33000.0
# 26    Color  James Cameron  ...          2.35               26000.0
# 285   Color  James Cameron  ...          2.35               13000.0
# 288   Color  James Cameron  ...          2.35                   0.0
# 599   Color  James Cameron  ...          2.35                   0.0
# 2455  Color  James Cameron  ...          1.85               18000.0
#
# [6 rows x 28 columns]

# %% [markdown]
# 4. 감독의 이름이 "James Cameron"인 데이터의 "imdb_score"의 평균을 구하시오.

# %%
movie[movie['director_name']=='James Cameron']['imdb_score'].mean()
# Out:
# 7.883333333333333

# %% [markdown]
# 5. "movie_title"을 index로 변경하시오.(reset_index)

# %%
movie.set_index('movie_title', inplace=True)
movie.head()
# Out:
#                                             color  ... movie_facebook_likes
# movie_title                                        ...
# Avatar                                      Color  ...              33000.0
# Pirates of the Caribbean: At World's End    Color  ...                  0.0
# Spectre                                     Color  ...              85000.0
# The Dark Knight Rises                       Color  ...             164000.0
# Star Wars: Episode VII - The Force Awakens    NaN  ...                  0.0
#
# [5 rows x 27 columns]

# %% [markdown]
# 6. index를 기준으로 데이터를 오름차순 정렬해 보시오.

# %%
movie.sort_index().head()
# Out:
#                             color  ... movie_facebook_likes
# movie_title                        ...
# 10 Days in a Madhouse       Color  ...              26000.0
# 10 Things I Hate About You  Color  ...              10000.0
# 10,000 B.C.                   NaN  ...                  0.0
# 102 Dalmatians              Color  ...                372.0
# 12 Monkeys                  Color  ...              12000.0
#
# [5 rows x 27 columns]

# %% [markdown]
# 7. 영화 "The Avengers" 이라는 영화의 "director_name","genres","title_year","imdb_score" 를 화면에 출력해 보시오.

# %%
movie.loc['The Avengers'][["director_name","genres","title_year","imdb_score" ]]
# Out:
# director_name                Joss Whedon
# genres           Action|Adventure|Sci-Fi
# title_year                          2012
# imdb_score                           8.1
# Name: The Avengers, dtype: object
